# %% [markdown]
# # Analysis

# %%
# Part 1 WeatherPy - Observable Trends

# %% [markdown]
# ![scatterplot_lat_temp.png](attachment:scatterplot_lat_temp.png)

# %%
# This scatterplot is showing the relationship between Latitude and Max Temperature. 
# There is a strong correlation, that may be non-linear. 
# This means the change of one does not correspond with the constant change of the other.
# There is a slight inverted parabola shape which could indicate an inverse relationship between the two.

# %% [markdown]
# ![nh_temp_lat_linreg.png](attachment:nh_temp_lat_linreg.png)

# %%
# The plot of Northern Hemisphere Maximum Temperatures shows a strong relationship with respect to Latitude. 
# The linear regression indicates there may be linear relationship between the variables.
# The negative slope shows a negative correlation/
# There is a decrease in temperature as we move up in latitude towards the Poles.
# And inversely an increase in temperature while moving towards the Equator.

# %% [markdown]
# ![sh_temp_lat_linreg.png](attachment:sh_temp_lat_linreg.png)

# %%
# The plot of Southern Hemisphere Maximum Temperatures shows a strong relationship with respect to Latitude. 
# This additional scatterplot confirms a negative correlation and strong relationship.
# The latitude is negative in the Southern Hemisphere (obviously) so the regression line shows a positive slope.
# The plot of the Northern and Southern Hemisphere mirror each other ande confirm the correlation.

# %%
# Part 2 VacationPy Maps - Showing Highest Humidities

# %% [markdown]
# ![Vacation_map.png](attachment:Vacation_map.png)

# %% [markdown]
# ![Heatmap.png](attachment:Heatmap.png)
