# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress

# Output File
output_data = "../output_data/cities.csv"
output_data
# Out:
# '../output_data/cities.csv'

# %%
# More Setup
import citipy
from citipy import citipy
import openweathermapy

# %%
# Read CSV
cities_df = pd.read_csv("../output_data/cities.csv")
cities_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
# Random lat and lng
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# Add the lat and lng to list
coordinates = list(lats_lngs)

# Create a list for cities
cities = []

# Identify the nearest city by lat and lng
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # Add unique cities to list
    if city not in cities:
        cities.append(city)

# Print city count
cities_count = len(cities)
print(cities_count)
# Out:
# 785

# %%
# Import API
from apikey import apikey
import requests
import json

apikey = "cde4a82bd500af477e5dc8b80410b974"
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=cde4a82bd500af477e5dc8b80410b974"

weather_response = requests.get(url)
weather_response

weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4, sort_keys=True))
weather_json.keys()
# Out:
# {
#     "city": {
#         "coord": {
#             "lat": 55.7522,
#             "lon": 37.6156
#         },
#         "country": "RU",
#         "id": 524901,
#         "name": "Moscow",
#         "population": 0,
#         "sunrise": 1601436644,
#         "sunset": 1601478482,
#         "timezone": 10800
#     },
#     "cnt": 40,
#     "cod": "200",
#     "list": [
#         {
#             "clouds": {
#                 "all": 66
#             },
#             "dt": 1601456400,
#             "dt_txt": "2020-09-30 09:00:00",
#             "main": {
#                 "feels_like": 282.42,
#                 "grnd_level": 1007,
#                 "humidity": 48,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "temp": 287.67,
#                 "temp_kf": -2.3,
#                 "temp_max": 289.97,
#                 "temp_min": 287.67
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 139,
#                 "speed": 5.52
#             }
#         },
#         {
#             "clouds": {
#                 "all": 70
#             },
#             "dt": 1601467200,
#             "dt_txt": "2020-09-30 12:00:00",
#             "main": {
#                 "feels_like": 284.83,
#                 "grnd_level": 1007,
#                 "humidity": 40,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "temp": 290.2,
#                 "temp_kf": -1.3,
#                 "temp_max": 291.5,
#                 "temp_min": 290.2
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 135,
#                 "speed": 5.61
#             }
#         },
#         {
#             "clouds": {
#                 "all": 85
#             },
#             "dt": 1601478000,
#             "dt_txt": "2020-09-30 15:00:00",
#             "main": {
#                 "feels_like": 284.4,
#                 "grnd_level": 1008,
#                 "humidity": 43,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "temp": 289.28,
#                 "temp_kf": -0.26,
#                 "temp_max": 289.54,
#                 "temp_min": 289.28
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 127,
#                 "speed": 4.97
#             }
#         },
#         {
#             "clouds": {
#                 "all": 75
#             },
#             "dt": 1601488800,
#             "dt_txt": "2020-09-30 18:00:00",
#             "main": {
#                 "feels_like": 282.97,
#                 "grnd_level": 1008,
#                 "humidity": 51,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "temp": 287.6,
#                 "temp_kf": -0.02,
#                 "temp_max": 287.62,
#                 "temp_min": 287.6
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 126,
#                 "speed": 4.85
#             }
#         },
#         {
#             "clouds": {
#                 "all": 28
#             },
#             "dt": 1601499600,
#             "dt_txt": "2020-09-30 21:00:00",
#             "main": {
#                 "feels_like": 282.08,
#                 "grnd_level": 1009,
#                 "humidity": 58,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "temp": 286.13,
#                 "temp_kf": 0,
#                 "temp_max": 286.13,
#                 "temp_min": 286.13
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 127,
#                 "speed": 4.15
#             }
#         },
#         {
#             "clouds": {
#                 "all": 29
#             },
#             "dt": 1601510400,
#             "dt_txt": "2020-10-01 00:00:00",
#             "main": {
#                 "feels_like": 281.19,
#                 "grnd_level": 1009,
#                 "humidity": 60,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "temp": 285.14,
#                 "temp_kf": 0,
#                 "temp_max": 285.14,
#                 "temp_min": 285.14
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 130,
#                 "speed": 3.89
#             }
#         },
#         {
#             "clouds": {
#                 "all": 55
#             },
#             "dt": 1601521200,
#             "dt_txt": "2020-10-01 03:00:00",
#             "main": {
#                 "feels_like": 280.54,
#                 "grnd_level": 1009,
#                 "humidity": 61,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "temp": 284.43,
#                 "temp_kf": 0,
#                 "temp_max": 284.43,
#                 "temp_min": 284.43
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 126,
#                 "speed": 3.68
#             }
#         },
#         {
#             "clouds": {
#                 "all": 51
#             },
#             "dt": 1601532000,
#             "dt_txt": "2020-10-01 06:00:00",
#             "main": {
#                 "feels_like": 282.04,
#                 "grnd_level": 1009,
#                 "humidity": 55,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "temp": 286.05,
#                 "temp_kf": 0,
#                 "temp_max": 286.05,
#                 "temp_min": 286.05
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 124,
#                 "speed": 3.86
#             }
#         },
#         {
#             "clouds": {
#                 "all": 41
#             },
#             "dt": 1601542800,
#             "dt_txt": "2020-10-01 09:00:00",
#             "main": {
#                 "feels_like": 285.47,
#                 "grnd_level": 1009,
#                 "humidity": 45,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "temp": 290.07,
#                 "temp_kf": 0,
#                 "temp_max": 290.07,
#                 "temp_min": 290.07
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 130,
#                 "speed": 4.94
#             }
#         },
#         {
#             "clouds": {
#                 "all": 42
#             },
#             "dt": 1601553600,
#             "dt_txt": "2020-10-01 12:00:00",
#             "main": {
#                 "feels_like": 285.48,
#                 "grnd_level": 1009,
#                 "humidity": 30,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "temp": 291.65,
#                 "temp_kf": 0,
#                 "temp_max": 291.65,
#                 "temp_min": 291.65
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 143,
#                 "speed": 6.1
#             }
#         },
#         {
#             "clouds": {
#                 "all": 21
#             },
#             "dt": 1601564400,
#             "dt_txt": "2020-10-01 15:00:00",
#             "main": {
#                 "feels_like": 285.06,
#                 "grnd_level": 1009,
#                 "humidity": 40,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "temp": 289.35,
#                 "temp_kf": 0,
#                 "temp_max": 289.35,
#                 "temp_min": 289.35
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 126,
#                 "speed": 3.88
#             }
#         },
#         {
#             "clouds": {
#                 "all": 33
#             },
#             "dt": 1601575200,
#             "dt_txt": "2020-10-01 18:00:00",
#             "main": {
#                 "feels_like": 282.97,
#                 "grnd_level": 1010,
#                 "humidity": 46,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "temp": 287.68,
#                 "temp_kf": 0,
#                 "temp_max": 287.68,
#                 "temp_min": 287.68
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 124,
#                 "speed": 4.59
#             }
#         },
#         {
#             "clouds": {
#                 "all": 14
#             },
#             "dt": 1601586000,
#             "dt_txt": "2020-10-01 21:00:00",
#             "main": {
#                 "feels_like": 281.81,
#                 "grnd_level": 1010,
#                 "humidity": 52,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 286.2,
#                 "temp_kf": 0,
#                 "temp_max": 286.2,
#                 "temp_min": 286.2
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 128,
#                 "speed": 4.23
#             }
#         },
#         {
#             "clouds": {
#                 "all": 56
#             },
#             "dt": 1601596800,
#             "dt_txt": "2020-10-02 00:00:00",
#             "main": {
#                 "feels_like": 281.21,
#                 "grnd_level": 1010,
#                 "humidity": 54,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 285.19,
#                 "temp_kf": 0,
#                 "temp_max": 285.19,
#                 "temp_min": 285.19
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 117,
#                 "speed": 3.55
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1601607600,
#             "dt_txt": "2020-10-02 03:00:00",
#             "main": {
#                 "feels_like": 280.2,
#                 "grnd_level": 1011,
#                 "humidity": 57,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 284.16,
#                 "temp_kf": 0,
#                 "temp_max": 284.16,
#                 "temp_min": 284.16
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 107,
#                 "speed": 3.46
#             }
#         },
#         {
#             "clouds": {
#                 "all": 95
#             },
#             "dt": 1601618400,
#             "dt_txt": "2020-10-02 06:00:00",
#             "main": {
#                 "feels_like": 281.24,
#                 "grnd_level": 1011,
#                 "humidity": 53,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 285.31,
#                 "temp_kf": 0,
#                 "temp_max": 285.31,
#                 "temp_min": 285.31
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 110,
#                 "speed": 3.64
#             }
#         },
#         {
#             "clouds": {
#                 "all": 95
#             },
#             "dt": 1601629200,
#             "dt_txt": "2020-10-02 09:00:00",
#             "main": {
#                 "feels_like": 285.01,
#                 "grnd_level": 1011,
#                 "humidity": 46,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 289.15,
#                 "temp_kf": 0,
#                 "temp_max": 289.15,
#                 "temp_min": 289.15
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 112,
#                 "speed": 4.14
#             }
#         },
#         {
#             "clouds": {
#                 "all": 92
#             },
#             "dt": 1601640000,
#             "dt_txt": "2020-10-02 12:00:00",
#             "main": {
#                 "feels_like": 287.03,
#                 "grnd_level": 1011,
#                 "humidity": 46,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 291.22,
#                 "temp_kf": 0,
#                 "temp_max": 291.22,
#                 "temp_min": 291.22
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 124,
#                 "speed": 4.76
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1601650800,
#             "dt_txt": "2020-10-02 15:00:00",
#             "main": {
#                 "feels_like": 286.1,
#                 "grnd_level": 1010,
#                 "humidity": 58,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 289.11,
#                 "temp_kf": 0,
#                 "temp_max": 289.11,
#                 "temp_min": 289.11
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 107,
#                 "speed": 3.54
#             }
#         },
#         {
#             "clouds": {
#                 "all": 99
#             },
#             "dt": 1601661600,
#             "dt_txt": "2020-10-02 18:00:00",
#             "main": {
#                 "feels_like": 284.43,
#                 "grnd_level": 1011,
#                 "humidity": 65,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 287.58,
#                 "temp_kf": 0,
#                 "temp_max": 287.58,
#                 "temp_min": 287.58
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 113,
#                 "speed": 3.81
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601672400,
#             "dt_txt": "2020-10-02 21:00:00",
#             "main": {
#                 "feels_like": 283.42,
#                 "grnd_level": 1011,
#                 "humidity": 69,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 286.4,
#                 "temp_kf": 0,
#                 "temp_max": 286.4,
#                 "temp_min": 286.4
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 110,
#                 "speed": 3.48
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601683200,
#             "dt_txt": "2020-10-03 00:00:00",
#             "main": {
#                 "feels_like": 282.64,
#                 "grnd_level": 1011,
#                 "humidity": 70,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 285.71,
#                 "temp_kf": 0,
#                 "temp_max": 285.71,
#                 "temp_min": 285.71
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 105,
#                 "speed": 3.46
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601694000,
#             "dt_txt": "2020-10-03 03:00:00",
#             "main": {
#                 "feels_like": 281.54,
#                 "grnd_level": 1011,
#                 "humidity": 70,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 284.91,
#                 "temp_kf": 0,
#                 "temp_max": 284.91,
#                 "temp_min": 284.91
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 103,
#                 "speed": 3.65
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601704800,
#             "dt_txt": "2020-10-03 06:00:00",
#             "main": {
#                 "feels_like": 282.16,
#                 "grnd_level": 1011,
#                 "humidity": 63,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 285.87,
#                 "temp_kf": 0,
#                 "temp_max": 285.87,
#                 "temp_min": 285.87
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 111,
#                 "speed": 3.94
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601715600,
#             "dt_txt": "2020-10-03 09:00:00",
#             "main": {
#                 "feels_like": 284.99,
#                 "grnd_level": 1011,
#                 "humidity": 51,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 289.15,
#                 "temp_kf": 0,
#                 "temp_max": 289.15,
#                 "temp_min": 289.15
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 114,
#                 "speed": 4.59
#             }
#         },
#         {
#             "clouds": {
#                 "all": 97
#             },
#             "dt": 1601726400,
#             "dt_txt": "2020-10-03 12:00:00",
#             "main": {
#                 "feels_like": 286.72,
#                 "grnd_level": 1011,
#                 "humidity": 44,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 290.9,
#                 "temp_kf": 0,
#                 "temp_max": 290.9,
#                 "temp_min": 290.9
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 115,
#                 "speed": 4.46
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1601737200,
#             "dt_txt": "2020-10-03 15:00:00",
#             "main": {
#                 "feels_like": 285.76,
#                 "grnd_level": 1011,
#                 "humidity": 51,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 289.06,
#                 "temp_kf": 0,
#                 "temp_max": 289.06,
#                 "temp_min": 289.06
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 113,
#                 "speed": 3.33
#             }
#         },
#         {
#             "clouds": {
#                 "all": 99
#             },
#             "dt": 1601748000,
#             "dt_txt": "2020-10-03 18:00:00",
#             "main": {
#                 "feels_like": 283.92,
#                 "grnd_level": 1012,
#                 "humidity": 51,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 287.74,
#                 "temp_kf": 0,
#                 "temp_max": 287.74,
#                 "temp_min": 287.74
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 111,
#                 "speed": 3.73
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601758800,
#             "dt_txt": "2020-10-03 21:00:00",
#             "main": {
#                 "feels_like": 282.99,
#                 "grnd_level": 1012,
#                 "humidity": 56,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 286.53,
#                 "temp_kf": 0,
#                 "temp_max": 286.53,
#                 "temp_min": 286.53
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 109,
#                 "speed": 3.39
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601769600,
#             "dt_txt": "2020-10-04 00:00:00",
#             "main": {
#                 "feels_like": 282.19,
#                 "grnd_level": 1011,
#                 "humidity": 63,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 285.58,
#                 "temp_kf": 0,
#                 "temp_max": 285.58,
#                 "temp_min": 285.58
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 101,
#                 "speed": 3.4
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601780400,
#             "dt_txt": "2020-10-04 03:00:00",
#             "main": {
#                 "feels_like": 281.48,
#                 "grnd_level": 1012,
#                 "humidity": 67,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 284.89,
#                 "temp_kf": 0,
#                 "temp_max": 284.89,
#                 "temp_min": 284.89
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 100,
#                 "speed": 3.5
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1601791200,
#             "dt_txt": "2020-10-04 06:00:00",
#             "main": {
#                 "feels_like": 282.03,
#                 "grnd_level": 1012,
#                 "humidity": 64,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 285.67,
#                 "temp_kf": 0,
#                 "temp_max": 285.67,
#                 "temp_min": 285.67
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 111,
#                 "speed": 3.85
#             }
#         },
#         {
#             "clouds": {
#                 "all": 88
#             },
#             "dt": 1601802000,
#             "dt_txt": "2020-10-04 09:00:00",
#             "main": {
#                 "feels_like": 285.02,
#                 "grnd_level": 1012,
#                 "humidity": 50,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 288.93,
#                 "temp_kf": 0,
#                 "temp_max": 288.93,
#                 "temp_min": 288.93
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 121,
#                 "speed": 4.09
#             }
#         },
#         {
#             "clouds": {
#                 "all": 88
#             },
#             "dt": 1601812800,
#             "dt_txt": "2020-10-04 12:00:00",
#             "main": {
#                 "feels_like": 286.32,
#                 "grnd_level": 1012,
#                 "humidity": 44,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 290.48,
#                 "temp_kf": 0,
#                 "temp_max": 290.48,
#                 "temp_min": 290.48
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 128,
#                 "speed": 4.32
#             }
#         },
#         {
#             "clouds": {
#                 "all": 85
#             },
#             "dt": 1601823600,
#             "dt_txt": "2020-10-04 15:00:00",
#             "main": {
#                 "feels_like": 284.96,
#                 "grnd_level": 1012,
#                 "humidity": 51,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 288.3,
#                 "temp_kf": 0,
#                 "temp_max": 288.3,
#                 "temp_min": 288.3
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 121,
#                 "speed": 3.19
#             }
#         },
#         {
#             "clouds": {
#                 "all": 52
#             },
#             "dt": 1601834400,
#             "dt_txt": "2020-10-04 18:00:00",
#             "main": {
#                 "feels_like": 283.07,
#                 "grnd_level": 1013,
#                 "humidity": 58,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "temp": 286.61,
#                 "temp_kf": 0,
#                 "temp_max": 286.61,
#                 "temp_min": 286.61
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 123,
#                 "speed": 3.55
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1601845200,
#             "dt_txt": "2020-10-04 21:00:00",
#             "main": {
#                 "feels_like": 282.18,
#                 "grnd_level": 1013,
#                 "humidity": 70,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "temp": 285.42,
#                 "temp_kf": 0,
#                 "temp_max": 285.42,
#                 "temp_min": 285.42
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 125,
#                 "speed": 3.62
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1601856000,
#             "dt_txt": "2020-10-05 00:00:00",
#             "main": {
#                 "feels_like": 281.38,
#                 "grnd_level": 1013,
#                 "humidity": 78,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "temp": 284.42,
#                 "temp_kf": 0,
#                 "temp_max": 284.42,
#                 "temp_min": 284.42
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 124,
#                 "speed": 3.54
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1601866800,
#             "dt_txt": "2020-10-05 03:00:00",
#             "main": {
#                 "feels_like": 280.57,
#                 "grnd_level": 1013,
#                 "humidity": 82,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "temp": 283.54,
#                 "temp_kf": 0,
#                 "temp_max": 283.54,
#                 "temp_min": 283.54
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 126,
#                 "speed": 3.4
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1601877600,
#             "dt_txt": "2020-10-05 06:00:00",
#             "main": {
#                 "feels_like": 281.05,
#                 "grnd_level": 1013,
#                 "humidity": 73,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "temp": 284.77,
#                 "temp_kf": 0,
#                 "temp_max": 284.77,
#                 "temp_min": 284.77
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 123,
#                 "speed": 4.3
#             }
#         }
#     ],
#     "message": 0
# }
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
# Print random city
print(weather_json["city"]["name"])
# Out:
# Moscow

# %%
# Empty list
cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0

print(f"Beginning Data Retrieval")   
print(f"-----------------------------")
    
# Loop through the list of cities

for city in cities:
    
    weather_response = requests.get(url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        
        cityname.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        
        print(f"Processing record {count} of Set 1 | {city}")
    except:
        print("City not Found. Skipping...") 
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of Set 1 | arlit
# Processing record 2 of Set 1 | busselton
# Processing record 3 of Set 1 | nikolskoye
# Processing record 4 of Set 1 | ahipara
# Processing record 5 of Set 1 | luderitz
# Processing record 6 of Set 1 | altay
# Processing record 7 of Set 1 | bluff
# Processing record 8 of Set 1 | plainview
# Processing record 9 of Set 1 | punta arenas
# Processing record 10 of Set 1 | provost
# Processing record 11 of Set 1 | cape town
# Processing record 12 of Set 1 | verkhnyaya maksakovka
# Processing record 13 of Set 1 | qaanaaq
# Processing record 14 of Set 1 | cabo san lucas
# Processing record 15 of Set 1 | port alfred
# Processing record 16 of Set 1 | mount gambier
# Processing record 17 of Set 1 | dikson
# Processing record 18 of Set 1 | ostashkov
# Processing record 19 of Set 1 | bambous virieux
# Processing record 20 of Set 1 | pedro juan caballero
# Processing record 21 of Set 1 | praxedis guerrero
# City not Found. Skipping...
# Processing record 22 of Set 1 | saint-philippe
# City not Found. Skipping...
# Processing record 23 of Set 1 | mahebourg
# Processing record 24 of Set 1 | ribeira grande
# Processing record 25 of Set 1 | abha
# City not Found. Skipping...
# Processing record 26 of Set 1 | tiruchchendur
# Processing record 27 of Set 1 | linfen
# Processing record 28 of Set 1 | kapaa
# Processing record 29 of Set 1 | hobart
# Processing record 30 of Set 1 | kavaratti
# Processing record 31 of Set 1 | coquimbo
# Processing record 32 of Set 1 | kodiak
# Processing record 33 of Set 1 | zolochiv
# Processing record 34 of Set 1 | cidreira
# Processing record 35 of Set 1 | omboue
# Processing record 36 of Set 1 | alcudia
# Processing record 37 of Set 1 | alofi
# Processing record 38 of Set 1 | upernavik
# Processing record 39 of Set 1 | uruzgan
# Processing record 40 of Set 1 | new norfolk
# Processing record 41 of Set 1 | mataura
# City not Found. Skipping...
# Processing record 42 of Set 1 | nyurba
# Processing record 43 of Set 1 | butaritari
# Processing record 44 of Set 1 | kruisfontein
# Processing record 45 of Set 1 | albany
# Processing record 46 of Set 1 | jamestown
# Processing record 47 of Set 1 | hambantota
# Processing record 48 of Set 1 | aneho
# Processing record 49 of Set 1 | nome
# Processing record 50 of Set 1 | axim
# Processing record 51 of Set 1 | hermanus
# Processing record 52 of Set 1 | port hawkesbury
# Processing record 53 of Set 1 | costinesti
# Processing record 54 of Set 1 | chirongui
# Processing record 55 of Set 1 | yellowknife
# Processing record 56 of Set 1 | castro
# Processing record 57 of Set 1 | brusque
# Processing record 58 of Set 1 | bogo
# Processing record 59 of Set 1 | atuona
# Processing record 60 of Set 1 | hvide sande
# Processing record 61 of Set 1 | adrar
# Processing record 62 of Set 1 | santa fe
# Processing record 63 of Set 1 | ushuaia
# Processing record 64 of Set 1 | dakar
# City not Found. Skipping...
# Processing record 65 of Set 1 | mahibadhoo
# Processing record 66 of Set 1 | reinbek
# Processing record 67 of Set 1 | ahuimanu
# Processing record 68 of Set 1 | port-gentil
# City not Found. Skipping...
# Processing record 69 of Set 1 | rikitea
# City not Found. Skipping...
# Processing record 70 of Set 1 | chiajna
# Processing record 71 of Set 1 | eyl
# Processing record 72 of Set 1 | vigrestad
# Processing record 73 of Set 1 | dunda
# Processing record 74 of Set 1 | pacific grove
# Processing record 75 of Set 1 | qaqortoq
# Processing record 76 of Set 1 | meadow lake
# Processing record 77 of Set 1 | pouebo
# Processing record 78 of Set 1 | washington
# Processing record 79 of Set 1 | rapid valley
# Processing record 80 of Set 1 | tres arroyos
# Processing record 81 of Set 1 | caravelas
# Processing record 82 of Set 1 | namibe
# Processing record 83 of Set 1 | zhigansk
# Processing record 84 of Set 1 | khabary
# Processing record 85 of Set 1 | mar del plata
# Processing record 86 of Set 1 | chokurdakh
# Processing record 87 of Set 1 | hanmer springs
# Processing record 88 of Set 1 | benghazi
# Processing record 89 of Set 1 | charyshskoye
# Processing record 90 of Set 1 | barra da estiva
# Processing record 91 of Set 1 | bredasdorp
# Processing record 92 of Set 1 | maple creek
# Processing record 93 of Set 1 | acapulco
# Processing record 94 of Set 1 | najran
# Processing record 95 of Set 1 | kitimat
# Processing record 96 of Set 1 | evensk
# Processing record 97 of Set 1 | ostrovnoy
# Processing record 98 of Set 1 | mehran
# Processing record 99 of Set 1 | acarau
# Processing record 100 of Set 1 | prince george
# Processing record 101 of Set 1 | mala tokmachka
# City not Found. Skipping...
# Processing record 102 of Set 1 | wum
# Processing record 103 of Set 1 | mackenzie
# Processing record 104 of Set 1 | port blair
# Processing record 105 of Set 1 | cervo
# Processing record 106 of Set 1 | balkhash
# City not Found. Skipping...
# Processing record 107 of Set 1 | longyearbyen
# Processing record 108 of Set 1 | maningrida
# Processing record 109 of Set 1 | methoni
# Processing record 110 of Set 1 | venado tuerto
# Processing record 111 of Set 1 | xining
# Processing record 112 of Set 1 | el tarra
# Processing record 113 of Set 1 | tautira
# Processing record 114 of Set 1 | iqaluit
# Processing record 115 of Set 1 | daru
# Processing record 116 of Set 1 | rosarito
# Processing record 117 of Set 1 | campanha
# Processing record 118 of Set 1 | butembo
# Processing record 119 of Set 1 | tomatlan
# Processing record 120 of Set 1 | akdepe
# Processing record 121 of Set 1 | la rioja
# Processing record 122 of Set 1 | naryan-mar
# Processing record 123 of Set 1 | pudozh
# City not Found. Skipping...
# Processing record 124 of Set 1 | itirucu
# Processing record 125 of Set 1 | kamiiso
# Processing record 126 of Set 1 | port augusta
# Processing record 127 of Set 1 | nha trang
# Processing record 128 of Set 1 | tulum
# Processing record 129 of Set 1 | tiksi
# Processing record 130 of Set 1 | yar-sale
# Processing record 131 of Set 1 | dharchula
# Processing record 132 of Set 1 | hrubieszow
# Processing record 133 of Set 1 | mehamn
# Processing record 134 of Set 1 | progreso
# Processing record 135 of Set 1 | cayenne
# Processing record 136 of Set 1 | sorland
# Processing record 137 of Set 1 | kiruna
# Processing record 138 of Set 1 | makakilo city
# Processing record 139 of Set 1 | burgeo
# Processing record 140 of Set 1 | barrow
# Processing record 141 of Set 1 | kaitangata
# Processing record 142 of Set 1 | tuktoyaktuk
# Processing record 143 of Set 1 | camacha
# Processing record 144 of Set 1 | thompson
# Processing record 145 of Set 1 | myrtle beach
# Processing record 146 of Set 1 | saint george
# Processing record 147 of Set 1 | thanh hoa
# Processing record 148 of Set 1 | olsztyn
# Processing record 149 of Set 1 | beira
# Processing record 150 of Set 1 | zyryanka
# Processing record 151 of Set 1 | banda aceh
# Processing record 152 of Set 1 | manado
# Processing record 153 of Set 1 | palmer
# Processing record 154 of Set 1 | hirara
# Processing record 155 of Set 1 | capinopolis
# Processing record 156 of Set 1 | pointe michel
# City not Found. Skipping...
# Processing record 157 of Set 1 | manokwari
# Processing record 158 of Set 1 | dinguiraye
# Processing record 159 of Set 1 | tenenkou
# Processing record 160 of Set 1 | naze
# Processing record 161 of Set 1 | shaping
# Processing record 162 of Set 1 | hithadhoo
# Processing record 163 of Set 1 | santa vitoria do palmar
# Processing record 164 of Set 1 | vila do maio
# Processing record 165 of Set 1 | romitan
# City not Found. Skipping...
# Processing record 166 of Set 1 | nemuro
# Processing record 167 of Set 1 | soe
# Processing record 168 of Set 1 | adeje
# Processing record 169 of Set 1 | vostok
# Processing record 170 of Set 1 | alice springs
# City not Found. Skipping...
# Processing record 171 of Set 1 | belaya gora
# City not Found. Skipping...
# City not Found. Skipping...
# Processing record 172 of Set 1 | esperance
# Processing record 173 of Set 1 | tessalit
# City not Found. Skipping...
# Processing record 174 of Set 1 | poso
# Processing record 175 of Set 1 | tekkali
# City not Found. Skipping...
# Processing record 176 of Set 1 | zhaotong
# Processing record 177 of Set 1 | khatanga
# Processing record 178 of Set 1 | byron bay
# Processing record 179 of Set 1 | puerto ayora
# Processing record 180 of Set 1 | jijiga
# Processing record 181 of Set 1 | excelsior springs
# Processing record 182 of Set 1 | phan thiet
# Processing record 183 of Set 1 | karratha
# City not Found. Skipping...
# Processing record 184 of Set 1 | norman wells
# Processing record 185 of Set 1 | huicheng
# Processing record 186 of Set 1 | baie-comeau
# Processing record 187 of Set 1 | newport
# Processing record 188 of Set 1 | rantoul
# Processing record 189 of Set 1 | shingu
# Processing record 190 of Set 1 | tahta
# Processing record 191 of Set 1 | remedios
# Processing record 192 of Set 1 | kahului
# Processing record 193 of Set 1 | batangafo
# Processing record 194 of Set 1 | chiriqui grande
# Processing record 195 of Set 1 | college
# Processing record 196 of Set 1 | blois
# Processing record 197 of Set 1 | virginia beach
# Processing record 198 of Set 1 | teguldet
# City not Found. Skipping...
# Processing record 199 of Set 1 | dalby
# Processing record 200 of Set 1 | chiang klang
# Processing record 201 of Set 1 | yulara
# City not Found. Skipping...
# Processing record 202 of Set 1 | port lincoln
# Processing record 203 of Set 1 | beringovskiy
# Processing record 204 of Set 1 | codrington
# Processing record 205 of Set 1 | vaini
# Processing record 206 of Set 1 | muros
# Processing record 207 of Set 1 | lorengau
# Processing record 208 of Set 1 | aklavik
# Processing record 209 of Set 1 | humaita
# Processing record 210 of Set 1 | tasiilaq
# Processing record 211 of Set 1 | yaroslavl
# Processing record 212 of Set 1 | masallatah
# Processing record 213 of Set 1 | miandoab
# Processing record 214 of Set 1 | victoria
# Processing record 215 of Set 1 | mandeville
# Processing record 216 of Set 1 | caruray
# Processing record 217 of Set 1 | provideniya
# Processing record 218 of Set 1 | ozernovskiy
# Processing record 219 of Set 1 | bengkulu
# City not Found. Skipping...
# Processing record 220 of Set 1 | haines junction
# Processing record 221 of Set 1 | otradnoye
# Processing record 222 of Set 1 | georgetown
# Processing record 223 of Set 1 | dzaoudzi
# Processing record 224 of Set 1 | okha
# Processing record 225 of Set 1 | saldanha
# Processing record 226 of Set 1 | port hardy
# Processing record 227 of Set 1 | kuito
# Processing record 228 of Set 1 | touros
# Processing record 229 of Set 1 | arraial do cabo
# Processing record 230 of Set 1 | sinjar
# Processing record 231 of Set 1 | lagoa
# Processing record 232 of Set 1 | reforma
# Processing record 233 of Set 1 | port macquarie
# Processing record 234 of Set 1 | kedrovyy
# Processing record 235 of Set 1 | debre tabor
# Processing record 236 of Set 1 | hilo
# Processing record 237 of Set 1 | el dorado
# Processing record 238 of Set 1 | madimba
# City not Found. Skipping...
# Processing record 239 of Set 1 | alba iulia
# Processing record 240 of Set 1 | ponta do sol
# Processing record 241 of Set 1 | svetlogorsk
# Processing record 242 of Set 1 | sioux lookout
# Processing record 243 of Set 1 | festus
# Processing record 244 of Set 1 | eregli
# Processing record 245 of Set 1 | severo-kurilsk
# Processing record 246 of Set 1 | gat
# Processing record 247 of Set 1 | lompoc
# Processing record 248 of Set 1 | narsaq
# Processing record 249 of Set 1 | lebu
# Processing record 250 of Set 1 | bathsheba
# Processing record 251 of Set 1 | pangnirtung
# Processing record 252 of Set 1 | koslan
# Processing record 253 of Set 1 | kenai
# Processing record 254 of Set 1 | pevek
# Processing record 255 of Set 1 | prince rupert
# City not Found. Skipping...
# Processing record 256 of Set 1 | imeni poliny osipenko
# Processing record 257 of Set 1 | mana
# Processing record 258 of Set 1 | kavieng
# Processing record 259 of Set 1 | paamiut
# Processing record 260 of Set 1 | ancud
# Processing record 261 of Set 1 | saskylakh
# City not Found. Skipping...
# Processing record 262 of Set 1 | ovalle
# Processing record 263 of Set 1 | vargashi
# City not Found. Skipping...
# Processing record 264 of Set 1 | jerecuaro
# Processing record 265 of Set 1 | uyutne
# Processing record 266 of Set 1 | cherskiy
# Processing record 267 of Set 1 | peno
# Processing record 268 of Set 1 | labuhan
# Processing record 269 of Set 1 | maceio
# Processing record 270 of Set 1 | praia da vitoria
# Processing record 271 of Set 1 | tarko-sale
# Processing record 272 of Set 1 | henties bay
# Processing record 273 of Set 1 | margate
# Processing record 274 of Set 1 | kloulklubed
# Processing record 275 of Set 1 | canton
# Processing record 276 of Set 1 | buchanan
# Processing record 277 of Set 1 | avarua
# Processing record 278 of Set 1 | machico
# Processing record 279 of Set 1 | killybegs
# Processing record 280 of Set 1 | luganville
# Processing record 281 of Set 1 | mercedes
# Processing record 282 of Set 1 | porto walter
# Processing record 283 of Set 1 | livramento
# Processing record 284 of Set 1 | kyra
# Processing record 285 of Set 1 | shache
# Processing record 286 of Set 1 | faya
# Processing record 287 of Set 1 | gull lake
# City not Found. Skipping...
# Processing record 288 of Set 1 | nuuk
# Processing record 289 of Set 1 | yerofey pavlovich
# Processing record 290 of Set 1 | faanui
# Processing record 291 of Set 1 | yegorlykskaya
# Processing record 292 of Set 1 | strezhevoy
# Processing record 293 of Set 1 | gerash
# City not Found. Skipping...
# Processing record 294 of Set 1 | clive
# Processing record 295 of Set 1 | sisimiut
# City not Found. Skipping...
# Processing record 296 of Set 1 | teya
# City not Found. Skipping...
# Processing record 297 of Set 1 | verdun
# Processing record 298 of Set 1 | russkaya polyana
# Processing record 299 of Set 1 | rosetta
# Processing record 300 of Set 1 | hasaki
# Processing record 301 of Set 1 | lensk
# Processing record 302 of Set 1 | otaru
# Processing record 303 of Set 1 | homer
# Processing record 304 of Set 1 | shahreza
# Processing record 305 of Set 1 | carnarvon
# City not Found. Skipping...
# Processing record 306 of Set 1 | north bend
# Processing record 307 of Set 1 | tual
# Processing record 308 of Set 1 | port hedland
# Processing record 309 of Set 1 | mogzon
# Processing record 310 of Set 1 | sao filipe
# Processing record 311 of Set 1 | kirakira
# Processing record 312 of Set 1 | nanortalik
# Processing record 313 of Set 1 | howard springs
# Processing record 314 of Set 1 | thinadhoo
# Processing record 315 of Set 1 | mount isa
# City not Found. Skipping...
# Processing record 316 of Set 1 | ketchikan
# Processing record 317 of Set 1 | constitucion
# Processing record 318 of Set 1 | la ronge
# Processing record 319 of Set 1 | de aar
# Processing record 320 of Set 1 | burnie
# Processing record 321 of Set 1 | jalu
# Processing record 322 of Set 1 | matamoros
# Processing record 323 of Set 1 | grindavik
# Processing record 324 of Set 1 | kondinskoye
# Processing record 325 of Set 1 | gazanjyk
# Processing record 326 of Set 1 | gizo
# Processing record 327 of Set 1 | takoradi
# Processing record 328 of Set 1 | tabuk
# Processing record 329 of Set 1 | palivere
# Processing record 330 of Set 1 | qingdao
# Processing record 331 of Set 1 | itoman
# Processing record 332 of Set 1 | broome
# Processing record 333 of Set 1 | winnemucca
# Processing record 334 of Set 1 | bikaner
# Processing record 335 of Set 1 | marrakesh
# Processing record 336 of Set 1 | lasa
# Processing record 337 of Set 1 | usinsk
# City not Found. Skipping...
# Processing record 338 of Set 1 | tianpeng
# Processing record 339 of Set 1 | sitka
# City not Found. Skipping...
# Processing record 340 of Set 1 | port elizabeth
# Processing record 341 of Set 1 | husavik
# Processing record 342 of Set 1 | vao
# Processing record 343 of Set 1 | ifakara
# Processing record 344 of Set 1 | praia
# Processing record 345 of Set 1 | iaciara
# Processing record 346 of Set 1 | san cristobal
# Processing record 347 of Set 1 | krasnyye baki
# Processing record 348 of Set 1 | hami
# Processing record 349 of Set 1 | penzance
# Processing record 350 of Set 1 | posse
# Processing record 351 of Set 1 | batemans bay
# Processing record 352 of Set 1 | inverness
# Processing record 353 of Set 1 | crotone
# Processing record 354 of Set 1 | cockburn town
# Processing record 355 of Set 1 | felanitx
# Processing record 356 of Set 1 | izhma
# Processing record 357 of Set 1 | yenagoa
# Processing record 358 of Set 1 | altamira
# Processing record 359 of Set 1 | gebze
# Processing record 360 of Set 1 | bethel
# Processing record 361 of Set 1 | hamilton
# Processing record 362 of Set 1 | pandan
# Processing record 363 of Set 1 | leshukonskoye
# Processing record 364 of Set 1 | blythe
# Processing record 365 of Set 1 | fairbanks
# Processing record 366 of Set 1 | hovd
# Processing record 367 of Set 1 | andilamena
# City not Found. Skipping...
# Processing record 368 of Set 1 | manaure
# Processing record 369 of Set 1 | pisco
# Processing record 370 of Set 1 | quatre cocos
# Processing record 371 of Set 1 | manicore
# Processing record 372 of Set 1 | san bartolome de tirajana
# Processing record 373 of Set 1 | galle
# Processing record 374 of Set 1 | fortuna
# Processing record 375 of Set 1 | zeerust
# Processing record 376 of Set 1 | oussouye
# Processing record 377 of Set 1 | simplicio mendes
# Processing record 378 of Set 1 | moose factory
# Processing record 379 of Set 1 | broken hill
# Processing record 380 of Set 1 | aksu
# Processing record 381 of Set 1 | coahuayana
# Processing record 382 of Set 1 | porbandar
# Processing record 383 of Set 1 | tabuleiro do norte
# Processing record 384 of Set 1 | bucerias
# Processing record 385 of Set 1 | sobolevo
# Processing record 386 of Set 1 | mandera
# Processing record 387 of Set 1 | mananjary
# City not Found. Skipping...
# Processing record 388 of Set 1 | fulton
# Processing record 389 of Set 1 | rawson
# Processing record 390 of Set 1 | srednekolymsk
# Processing record 391 of Set 1 | dulce nombre de culmi
# Processing record 392 of Set 1 | east london
# Processing record 393 of Set 1 | nishihara
# Processing record 394 of Set 1 | gradsko
# Processing record 395 of Set 1 | soyo
# City not Found. Skipping...
# Processing record 396 of Set 1 | ellensburg
# Processing record 397 of Set 1 | port-cartier
# Processing record 398 of Set 1 | wloszczowa
# Processing record 399 of Set 1 | kobayashi
# Processing record 400 of Set 1 | copiapo
# Processing record 401 of Set 1 | flinders
# Processing record 402 of Set 1 | blantyre
# Processing record 403 of Set 1 | hanna
# Processing record 404 of Set 1 | olafsvik
# Processing record 405 of Set 1 | soverato
# Processing record 406 of Set 1 | puerto escondido
# Processing record 407 of Set 1 | yanji
# Processing record 408 of Set 1 | lukoyanov
# Processing record 409 of Set 1 | clyde river
# Processing record 410 of Set 1 | weinan
# Processing record 411 of Set 1 | charlotte
# Processing record 412 of Set 1 | sterling
# Processing record 413 of Set 1 | bahia blanca
# Processing record 414 of Set 1 | harwich
# Processing record 415 of Set 1 | yuncheng
# Processing record 416 of Set 1 | billings
# Processing record 417 of Set 1 | maniitsoq
# City not Found. Skipping...
# Processing record 418 of Set 1 | xicotencatl
# Processing record 419 of Set 1 | helong
# Processing record 420 of Set 1 | scottsbluff
# Processing record 421 of Set 1 | mogadishu
# Processing record 422 of Set 1 | calbuco
# Processing record 423 of Set 1 | tsabong
# Processing record 424 of Set 1 | vardo
# Processing record 425 of Set 1 | amapa
# Processing record 426 of Set 1 | honningsvag
# Processing record 427 of Set 1 | pyshma
# Processing record 428 of Set 1 | kletnya
# Processing record 429 of Set 1 | udachnyy
# Processing record 430 of Set 1 | samarai
# Processing record 431 of Set 1 | kidal
# Processing record 432 of Set 1 | grand gaube
# Processing record 433 of Set 1 | tyukhtet
# Processing record 434 of Set 1 | joshimath
# Processing record 435 of Set 1 | santa isabel
# Processing record 436 of Set 1 | ilulissat
# Processing record 437 of Set 1 | laguna
# Processing record 438 of Set 1 | vung tau
# Processing record 439 of Set 1 | qinzhou
# Processing record 440 of Set 1 | yumen
# Processing record 441 of Set 1 | antofagasta
# Processing record 442 of Set 1 | parrita
# Processing record 443 of Set 1 | tevaitoa
# Processing record 444 of Set 1 | teluknaga
# Processing record 445 of Set 1 | saldana
# Processing record 446 of Set 1 | natal
# Processing record 447 of Set 1 | sidi ali
# Processing record 448 of Set 1 | urengoy
# Processing record 449 of Set 1 | izumo
# Processing record 450 of Set 1 | mattru
# Processing record 451 of Set 1 | biloela
# Processing record 452 of Set 1 | sinnamary
# Processing record 453 of Set 1 | mumford
# Processing record 454 of Set 1 | airai
# Processing record 455 of Set 1 | beian
# Processing record 456 of Set 1 | urgut
# Processing record 457 of Set 1 | miranda
# Processing record 458 of Set 1 | ust-kuyga
# City not Found. Skipping...
# Processing record 459 of Set 1 | alencon
# Processing record 460 of Set 1 | mitsamiouli
# Processing record 461 of Set 1 | galesong
# Processing record 462 of Set 1 | timaru
# Processing record 463 of Set 1 | klaksvik
# Processing record 464 of Set 1 | shizuishan
# Processing record 465 of Set 1 | geraldton
# Processing record 466 of Set 1 | abalak
# Processing record 467 of Set 1 | marzuq
# Processing record 468 of Set 1 | panyutyne
# Processing record 469 of Set 1 | biu
# Processing record 470 of Set 1 | saiha
# Processing record 471 of Set 1 | ixtapa
# Processing record 472 of Set 1 | kununurra
# Processing record 473 of Set 1 | comodoro rivadavia
# Processing record 474 of Set 1 | gloversville
# Processing record 475 of Set 1 | plymouth
# Processing record 476 of Set 1 | khani
# Processing record 477 of Set 1 | dalbandin
# City not Found. Skipping...
# Processing record 478 of Set 1 | kathu
# City not Found. Skipping...
# City not Found. Skipping...
# Processing record 479 of Set 1 | ossora
# Processing record 480 of Set 1 | padang
# Processing record 481 of Set 1 | gravdal
# Processing record 482 of Set 1 | malartic
# Processing record 483 of Set 1 | cansancao
# Processing record 484 of Set 1 | dahra
# Processing record 485 of Set 1 | filadelfia
# Processing record 486 of Set 1 | isangel
# Processing record 487 of Set 1 | kropotkin
# Processing record 488 of Set 1 | opuwo
# Processing record 489 of Set 1 | vengerovo
# Processing record 490 of Set 1 | kailua
# Processing record 491 of Set 1 | poitiers
# Processing record 492 of Set 1 | elk plain
# Processing record 493 of Set 1 | niquelandia
# Processing record 494 of Set 1 | san martin
# Processing record 495 of Set 1 | sao jose da coroa grande
# Processing record 496 of Set 1 | mikhaylovka
# Processing record 497 of Set 1 | pizarro
# Processing record 498 of Set 1 | la libertad
# Processing record 499 of Set 1 | cozumel
# Processing record 500 of Set 1 | chuy
# Processing record 501 of Set 1 | pareora
# Processing record 502 of Set 1 | bani
# Processing record 503 of Set 1 | bilma
# City not Found. Skipping...
# Processing record 504 of Set 1 | torbay
# Processing record 505 of Set 1 | brae
# Processing record 506 of Set 1 | hualmay
# Processing record 507 of Set 1 | atar
# Processing record 508 of Set 1 | san quintin
# Processing record 509 of Set 1 | puertollano
# Processing record 510 of Set 1 | balaipungut
# City not Found. Skipping...
# Processing record 511 of Set 1 | svetlyy
# Processing record 512 of Set 1 | longhua
# Processing record 513 of Set 1 | pangody
# Processing record 514 of Set 1 | tingo maria
# City not Found. Skipping...
# Processing record 515 of Set 1 | dwarka
# City not Found. Skipping...
# Processing record 516 of Set 1 | ponta delgada
# Processing record 517 of Set 1 | meulaboh
# Processing record 518 of Set 1 | jizan
# Processing record 519 of Set 1 | vila franca do campo
# Processing record 520 of Set 1 | kilmallock
# Processing record 521 of Set 1 | westport
# Processing record 522 of Set 1 | yong peng
# Processing record 523 of Set 1 | killarney
# Processing record 524 of Set 1 | garissa
# Processing record 525 of Set 1 | novomykolayivka
# Processing record 526 of Set 1 | nirmal
# Processing record 527 of Set 1 | atambua
# Processing record 528 of Set 1 | talnakh
# Processing record 529 of Set 1 | richards bay
# Processing record 530 of Set 1 | suntar
# Processing record 531 of Set 1 | paraiso
# City not Found. Skipping...
# City not Found. Skipping...
# Processing record 532 of Set 1 | the pas
# Processing record 533 of Set 1 | novobataysk
# Processing record 534 of Set 1 | gorontalo
# Processing record 535 of Set 1 | ayan
# Processing record 536 of Set 1 | ballina
# Processing record 537 of Set 1 | zelenoborskiy
# Processing record 538 of Set 1 | lilongwe
# Processing record 539 of Set 1 | tulun
# Processing record 540 of Set 1 | souillac
# Processing record 541 of Set 1 | bima
# Processing record 542 of Set 1 | hofn
# Processing record 543 of Set 1 | novyy urgal
# Processing record 544 of Set 1 | aswan
# Processing record 545 of Set 1 | aykhal
# Processing record 546 of Set 1 | shirokiy
# Processing record 547 of Set 1 | flin flon
# Processing record 548 of Set 1 | guerrero negro
# Processing record 549 of Set 1 | moengo
# Processing record 550 of Set 1 | trincomalee
# Processing record 551 of Set 1 | nizwa
# Processing record 552 of Set 1 | riyadh
# Processing record 553 of Set 1 | kalmunai
# Processing record 554 of Set 1 | abeche
# Processing record 555 of Set 1 | kushmurun
# Processing record 556 of Set 1 | leningradskiy
# Processing record 557 of Set 1 | campo grande
# Processing record 558 of Set 1 | linhares
# Processing record 559 of Set 1 | manjacaze
# Processing record 560 of Set 1 | okhotsk
# Processing record 561 of Set 1 | lavrentiya
# Processing record 562 of Set 1 | vestmannaeyjar
# Processing record 563 of Set 1 | manitouwadge
# Processing record 564 of Set 1 | marawi
# Processing record 565 of Set 1 | petawawa
# Processing record 566 of Set 1 | imphal
# City not Found. Skipping...
# Processing record 567 of Set 1 | sibolga
# Processing record 568 of Set 1 | puerto narino
# Processing record 569 of Set 1 | vila velha
# Processing record 570 of Set 1 | tuatapere
# Processing record 571 of Set 1 | kaeo
# City not Found. Skipping...
# Processing record 572 of Set 1 | rawlins
# Processing record 573 of Set 1 | teahupoo
# Processing record 574 of Set 1 | san patricio
# Processing record 575 of Set 1 | ferme-neuve
# Processing record 576 of Set 1 | amga
# Processing record 577 of Set 1 | tobol
# Processing record 578 of Set 1 | san francisco
# Processing record 579 of Set 1 | lashio
# Processing record 580 of Set 1 | lata
# Processing record 581 of Set 1 | asfi
# City not Found. Skipping...
# Processing record 582 of Set 1 | lidkoping
# City not Found. Skipping...
# Processing record 583 of Set 1 | gisborne
# Processing record 584 of Set 1 | malanje
# Processing record 585 of Set 1 | taoudenni
# Processing record 586 of Set 1 | sorgues
# Processing record 587 of Set 1 | ornskoldsvik
# Processing record 588 of Set 1 | kano
# Processing record 589 of Set 1 | wilmington
# Processing record 590 of Set 1 | sandwick
# Processing record 591 of Set 1 | borovskoy
# Processing record 592 of Set 1 | nanakuli
# Processing record 593 of Set 1 | kemi
# Processing record 594 of Set 1 | miraflores
# Processing record 595 of Set 1 | durango
# Processing record 596 of Set 1 | bacalan
# Processing record 597 of Set 1 | rabo de peixe
# Processing record 598 of Set 1 | pochutla
# Processing record 599 of Set 1 | berlevag
# City not Found. Skipping...
# Processing record 600 of Set 1 | pafos
# Processing record 601 of Set 1 | tura
# Processing record 602 of Set 1 | sarkand
# Processing record 603 of Set 1 | carutapera
# Processing record 604 of Set 1 | manzanillo
# Processing record 605 of Set 1 | magalia
# Processing record 606 of Set 1 | nan
# Processing record 607 of Set 1 | zhucheng
# Processing record 608 of Set 1 | zamania
# Processing record 609 of Set 1 | matadi
# City not Found. Skipping...
# Processing record 610 of Set 1 | oranjemund
# Processing record 611 of Set 1 | tucuman
# Processing record 612 of Set 1 | belyy yar
# Processing record 613 of Set 1 | avera
# Processing record 614 of Set 1 | kilrush
# Processing record 615 of Set 1 | komsomolskiy
# Processing record 616 of Set 1 | campoverde
# Processing record 617 of Set 1 | barranca
# Processing record 618 of Set 1 | baykit
# Processing record 619 of Set 1 | ola
# Processing record 620 of Set 1 | wakefield
# Processing record 621 of Set 1 | nara
# Processing record 622 of Set 1 | kamaishi
# City not Found. Skipping...
# Processing record 623 of Set 1 | clovis
# Processing record 624 of Set 1 | ayorou
# City not Found. Skipping...
# Processing record 625 of Set 1 | hobyo
# Processing record 626 of Set 1 | troina
# Processing record 627 of Set 1 | drochia
# Processing record 628 of Set 1 | mnogovershinnyy
# Processing record 629 of Set 1 | mabaruma
# Processing record 630 of Set 1 | jedrzejow
# Processing record 631 of Set 1 | cap-aux-meules
# City not Found. Skipping...
# Processing record 632 of Set 1 | mandalgovi
# Processing record 633 of Set 1 | wanning
# Processing record 634 of Set 1 | katherine
# Processing record 635 of Set 1 | ler
# Processing record 636 of Set 1 | bambanglipuro
# Processing record 637 of Set 1 | itarema
# Processing record 638 of Set 1 | fukue
# Processing record 639 of Set 1 | houma
# Processing record 640 of Set 1 | pankrushikha
# Processing record 641 of Set 1 | matay
# Processing record 642 of Set 1 | troutdale
# City not Found. Skipping...
# Processing record 643 of Set 1 | bonthe
# Processing record 644 of Set 1 | la paz
# Processing record 645 of Set 1 | venice
# Processing record 646 of Set 1 | latung
# Processing record 647 of Set 1 | kilindoni
# Processing record 648 of Set 1 | lethem
# Processing record 649 of Set 1 | chebenki
# City not Found. Skipping...
# City not Found. Skipping...
# Processing record 650 of Set 1 | calmar
# Processing record 651 of Set 1 | cururupu
# Processing record 652 of Set 1 | kolobrzeg
# Processing record 653 of Set 1 | athabasca
# Processing record 654 of Set 1 | zhezkazgan
# Processing record 655 of Set 1 | sembakung
# Processing record 656 of Set 1 | guiratinga
# Processing record 657 of Set 1 | ilheus
# Processing record 658 of Set 1 | saint-joseph
# Processing record 659 of Set 1 | pangai
# Processing record 660 of Set 1 | douglas
# Processing record 661 of Set 1 | klyuchi
# Processing record 662 of Set 1 | noyabrsk
# Processing record 663 of Set 1 | rio amarillo
# Processing record 664 of Set 1 | aguimes
# Processing record 665 of Set 1 | melk
# Processing record 666 of Set 1 | san angelo
# Processing record 667 of Set 1 | katsuura
# Processing record 668 of Set 1 | point pleasant
# Processing record 669 of Set 1 | fallon
# Processing record 670 of Set 1 | pakxan
# Processing record 671 of Set 1 | akureyri
# Processing record 672 of Set 1 | naples
# Processing record 673 of Set 1 | dali
# Processing record 674 of Set 1 | erzin
# Processing record 675 of Set 1 | borzya
# Processing record 676 of Set 1 | concarneau
# Processing record 677 of Set 1 | le moule
# Processing record 678 of Set 1 | araouane
# City not Found. Skipping...
# Processing record 679 of Set 1 | benito juarez
# Processing record 680 of Set 1 | yima
# Processing record 681 of Set 1 | nuevo progreso
# Processing record 682 of Set 1 | vadso
# City not Found. Skipping...
# Processing record 683 of Set 1 | tecoanapa
# Processing record 684 of Set 1 | fort pierce
# Processing record 685 of Set 1 | batticaloa
# Processing record 686 of Set 1 | maniago
# Processing record 687 of Set 1 | rincon
# Processing record 688 of Set 1 | basoko
# Processing record 689 of Set 1 | kiama
# Processing record 690 of Set 1 | vilyuysk
# Processing record 691 of Set 1 | dunedin
# Processing record 692 of Set 1 | egvekinot
# Processing record 693 of Set 1 | asau
# Processing record 694 of Set 1 | mayo
# Processing record 695 of Set 1 | qui nhon
# Processing record 696 of Set 1 | zgorzelec
# Processing record 697 of Set 1 | lerwick
# Processing record 698 of Set 1 | kupang
# Processing record 699 of Set 1 | djenne
# City not Found. Skipping...
# Processing record 700 of Set 1 | goumenissa
# Processing record 701 of Set 1 | yerbogachen
# Processing record 702 of Set 1 | sao felix do xingu
# Processing record 703 of Set 1 | hoeselt
# City not Found. Skipping...
# Processing record 704 of Set 1 | namatanai
# Processing record 705 of Set 1 | carlsbad
# Processing record 706 of Set 1 | ginir
# Processing record 707 of Set 1 | socorro
# Processing record 708 of Set 1 | le mans
# Processing record 709 of Set 1 | salalah
# Processing record 710 of Set 1 | mendi
# Processing record 711 of Set 1 | anadyr
# Processing record 712 of Set 1 | hutchinson
# Processing record 713 of Set 1 | saint-augustin
# Processing record 714 of Set 1 | benjamin aceval
# City not Found. Skipping...
# Processing record 715 of Set 1 | damavand
# Processing record 716 of Set 1 | potoci
# Processing record 717 of Set 1 | kamarion
# Processing record 718 of Set 1 | port hueneme
# Processing record 719 of Set 1 | olney
# City not Found. Skipping...
# Processing record 720 of Set 1 | deputatskiy

# %%
# Create df
records = ({"Country":country,"City": cityname, "Latitude": lat, "Longitude":lng, "Max Temp":max_temp, 
                       "Humidity":humidity,"Cloudiness":cloudiness,"Wind Speed":wind_speed,"Date":date})
weather_response_df = pd.DataFrame(records)
weather_response_df.head()
# Out:
#   Country        City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0      NE       Arlit   18.7369     7.3853     97.66        13          40
# 1      AU   Busselton  -33.6500   115.3333     62.80        74         100
# 2      RU  Nikolskoye   59.7035    30.7861     59.59        80          67
# 3      NZ     Ahipara  -35.1667   173.1667     52.88        73          18
# 4      NA    Lüderitz  -26.6481    15.1594     66.27        55           0
#
#    Wind Speed        Date
# 0        3.22  1601456400
# 1       13.82  1601456400
# 2        4.00  1601456400
# 3        5.64  1601456400
# 4       24.81  1601456400

# %%
# New CSV
weather_response_df.to_csv(r"../output_data/weather_response.csv")

# %%
# Remove Humidity above 100%
city_data = weather_response_df.loc[weather_response_df['Humidity'] >= 100]
city_data.head()
# Out:
#     Country   City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 709      PG  Mendi   -6.1761   143.6513     58.53       100          96
#
#      Wind Speed        Date
# 709        0.85  1601456400

# %%
# Indices if there were cities with Humidity above 100%
index=100
city_data_df = city_data.index

# %%
# Passing "inplace=False" will make a copy of the city_data DataFrame, called "clean_city_data"
city_data = weather_response_df.loc[weather_response_df['Humidity']<99]
clean_city_data_df = city_data.dropna(inplace=False) 
clean_city_data_df.head()
# Out:
#   Country        City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0      NE       Arlit   18.7369     7.3853     97.66        13          40
# 1      AU   Busselton  -33.6500   115.3333     62.80        74         100
# 2      RU  Nikolskoye   59.7035    30.7861     59.59        80          67
# 3      NZ     Ahipara  -35.1667   173.1667     52.88        73          18
# 4      NA    Lüderitz  -26.6481    15.1594     66.27        55           0
#
#    Wind Speed        Date
# 0        3.22  1601456400
# 1       13.82  1601456400
# 2        4.00  1601456400
# 3        5.64  1601456400
# 4       24.81  1601456400

# %%
## Scatterplots
# Latitude vs Temperature (F) 
# Latitude vs Humidity (%)
# Latitude vs Cloudiness (%)
# Latitude vs Wind Speed (mph)

# %%
# Lat vs Temp
lat = weather_response_df["Latitude"]
temp = weather_response_df["Max Temp"]

plt.scatter(lat, temp, color = "r", marker='o')
plt.title('Latitude vs Temperature')
plt.xlabel('Latitude (Degrees)')
plt.ylabel('Max Temperature (Fahrenheit)')
plt.grid()
plt.savefig('../output_data/scatterplot_lat_temp')
print("This scatterplot is showing the relationship between Latitude and Max Temperature.")
plt.show()

# %%
# Lat vs Hum
lat = weather_response_df["Latitude"]
hum = weather_response_df["Humidity"]

plt.scatter(lat, hum, color = "y", marker='o')
plt.title('Latitude vs Humdity')
plt.xlabel('Latitude (Degrees)')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig('../output_data/scatterplot_lat_hum')
print("This scatterplot is showing the relationship between Latitude and Humidity.")
plt.show()

# %%
# Lat vs Cloud
lat = weather_response_df["Latitude"]
cloud = weather_response_df["Cloudiness"]

plt.scatter(lat, cloud, color = "c", marker='o')
plt.title('Latitude vs Cloudiness')
plt.xlabel('Latitude (Degrees)')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig('../output_data/scatterplot_lat_cloud')
print("This scatterplot is showing the relationship between Latitude and Cloudiness.")
plt.show()

# %%
# Lat vs Wind
lat = weather_response_df["Latitude"]
wind = weather_response_df["Wind Speed"]

plt.scatter(lat, wind, color = "m", marker='o')
plt.title('Latitude vs Wind Speed')
plt.xlabel('Latitude (Degrees)')
plt.ylabel('Windspeed (MPH)')
plt.grid()
plt.savefig('../output_data/scatterplot_lat_wind')
print("This scatterplot is showing the relationship between Latitude and Wind Speed.")
plt.show()

# %%
# Separate by Hemisphere
north_hemi_df = weather_response_df.loc[weather_response_df['Latitude']>=0]
south_hemi_df = weather_response_df.loc[weather_response_df['Latitude']<0]

x_val = weather_response_df["Latitude"]
x_val.count
# Out:
# <bound method Series.count of 0      18.7369
# 1     -33.6500
# 2      59.7035
# 3     -35.1667
# 4     -26.6481
#         ...
# 715    43.4086
# 716    36.8000
# 717    34.1478
# 718    39.1532
# 719    69.3000
# Name: Latitude, Length: 720, dtype: float64>

# %%
## Linear Regression
# Northern Hemisphere - Temperature (F) vs. Latitude
# Southern Hemisphere - Temperature (F) vs. Latitude
# Northern Hemisphere - Humidity (%) vs. Latitude
# Southern Hemisphere - Humidity (%) vs. Latitude
# Northern Hemisphere - Cloudiness (%) vs. Latitude
# Southern Hemisphere - Cloudiness (%) vs. Latitude
# Northern Hemisphere - Wind Speed (mph) vs. Latitude
# Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
# Northern Hemisphere- Max Temp vs. Latitude Linear Regression
x_val = north_hemi_df['Latitude']
y_val = north_hemi_df['Max Temp']

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter 
plt.scatter(x_val,y_val)

# Plot line
plt.plot(x_val,regress_values,"r-")
plt.annotate(line_eq,(20,28),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude - Linear Regression')
plt.savefig('../output_data/nh_temp_lat_linreg')
plt.show()

# Comments
print(f"R squared: {rvalue**2}")
print("The figure shows a strong correlation between Latitude and Max Temps in the Northern Hemisphere.")
# Out:
# R squared: 0.6962542859361032
# The figure shows a strong correlation between Latitude and Max Temps in the Northern Hemisphere.

# %%
# Southern Hemisphere- Max Temp vs. Latitude Linear Regression
x_val = south_hemi_df['Latitude']
y_val = south_hemi_df['Max Temp']

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter 
plt.scatter(x_val,y_val)

# Plot line
plt.plot(x_val,regress_values,"r-")
plt.annotate(line_eq,(20,28),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude - Linear Regression')
plt.savefig('../output_data/sh_temp_lat_linreg')
plt.show()

# Comments
print(f"R squared: {rvalue**2}")
print("The figure also shows a strong correlation between Latitude and Max Temps in the Southern Hemisphere.")
# Out:
# R squared: 0.6019467341382265
# The figure also shows a strong correlation between Latitude and Max Temps in the Southern Hemisphere.

# %%
# Northern Hemisphere- Humidity vs. Latitude Linear Regression
x_val = north_hemi_df['Latitude']
y_val = north_hemi_df['Humidity']

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter 
plt.scatter(x_val,y_val)

# Plot line
plt.plot(x_val,regress_values,"r-")
plt.annotate(line_eq,(20,28),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity vs. Latitude - Linear Regression')
plt.savefig('../output_data/nh_hum_lat_linreg')
plt.show()

# Comments
print(f"R squared: {rvalue**2}")
print("The figure shows a weak correlation between Latitude and Humidity in the Northern Hemisphere.")
# Out:
# R squared: 0.02520697704449974
# The figure shows a weak correlation between Latitude and Humidity in the Northern Hemisphere.

# %%
# Southern Hemisphere- Humidity vs. Latitude Linear Regression
x_val = south_hemi_df['Latitude']
y_val = south_hemi_df['Humidity']

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter 
plt.scatter(x_val,y_val)

# Plot line
plt.plot(x_val,regress_values,"r-")
plt.annotate(line_eq,(20,28),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity vs. Latitude - Linear Regression')
plt.savefig('../output_data/sh_hum_lat_linreg')
plt.show()

# Comments
print(f"R squared: {rvalue**2}")
print("The figure shows a weak correlation between Latitude and Humidity in the Southern Hemisphere.")
# Out:
# R squared: 0.0004490339664983881
# The figure shows a weak correlation between Latitude and Humidity in the Southern Hemisphere.

# %%
# Northern Hemisphere- Cloudiness vs. Latitude Linear Regression
x_val = north_hemi_df['Latitude']
y_val = north_hemi_df['Cloudiness']

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter 
plt.scatter(x_val,y_val)

# Plot line
plt.plot(x_val,regress_values,"r-")
plt.annotate(line_eq,(20,28),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude - Linear Regression')
plt.savefig('../output_data/nh_cloud_lat_linreg')
plt.show()

# Comments
print(f"R squared: {rvalue**2}")
print("The figure shows a weak correlation between Latitude and Cloudiness in the Northern Hemisphere.")
# Out:
# R squared: 0.002559524708430498
# The figure shows a weak correlation between Latitude and Cloudiness in the Northern Hemisphere.

# %%
# Southern Hemisphere- Cloudiness vs. Latitude Linear Regression
x_val = south_hemi_df['Latitude']
y_val = south_hemi_df['Cloudiness']

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter 
plt.scatter(x_val,y_val)

# Plot line
plt.plot(x_val,regress_values,"r-")
plt.annotate(line_eq,(20,28),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude - Linear Regression')
plt.savefig('../output_data/sh_cloud_lat_linreg')
plt.show()

# Comments
print(f"R squared: {rvalue**2}")
print("The figure shows a weak correlation between Latitude and Cloudiness in the Southern Hemisphere.")
# Out:
# R squared: 0.004535343810517412
# The figure shows a weak correlation between Latitude and Cloudiness in the Southern Hemisphere.

# %%
# Northern Hemisphere- Wind Speed vs. Latitude Linear Regression
x_val = north_hemi_df['Latitude']
y_val = north_hemi_df['Wind Speed']

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter 
plt.scatter(x_val,y_val)

# Plot line
plt.plot(x_val,regress_values,"r-")
plt.annotate(line_eq,(20,28),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude - Linear Regression')
plt.savefig('../output_data/nh_ws_lat_linreg')
plt.show()

# Comments
print(f"R squared: {rvalue**2}")
print("The figure shows no clear correlation between Latitude and Wind Speed in the Northern Hemisphere. The data set shows a flat line of regression and is evenly distributed.")
# Out:
# R squared: 0.01937619934332165
# The figure shows no clear correlation between Latitude and Wind Speed in the Northern Hemisphere. The data set shows a flat line of regression and is evenly distributed.

# %%
# Southern Hemisphere- Wind Speed vs. Latitude Linear Regression
x_val = south_hemi_df['Latitude']
y_val = south_hemi_df['Wind Speed']

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter 
plt.scatter(x_val,y_val)

# Plot line
plt.plot(x_val,regress_values,"r-")
plt.annotate(line_eq,(20,28),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude - Linear Regression')
plt.savefig('../output_data/sh_ws_lat_linreg')
plt.show()

# Comments
print(f"R squared: {rvalue**2}")
print("The figure shows a somewhat strong correlation between Latitude and Wind Speed in the Southern Hemisphere. The wind speed tends to be lower and the correlation is stronger approaching a 0 value Latitude.")
# Out:
# R squared: 0.008442421146233734
# The figure shows a somewhat strong correlation between Latitude and Wind Speed in the Southern Hemisphere. The wind speed tends to be lower and the correlation is stronger approaching a 0 value Latitude.
